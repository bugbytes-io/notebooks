# %% [markdown]
# ## Pandas: querying DataFrames.
#
# The data is football data, which comes from: https://sports-statistics.com/sports-data/soccer-datasets/

# %%
import pandas as pd

# %%
df = pd.read_csv('https://sports-statistics.com/database/soccer-data/england-premier-league-2019-to-2020.csv')
df.head()
# Out:
#   Div        Date   Time        HomeTeam  ... MaxCAHH  MaxCAHA  AvgCAHH AvgCAHA
# 0  E0  09/08/2019  20:00       Liverpool  ...    1.99     2.07     1.90    1.99
# 1  E0  10/08/2019  12:30        West Ham  ...    2.07     1.98     1.97    1.92
# 2  E0  10/08/2019  15:00     Bournemouth  ...    2.00     1.96     1.96    1.92
# 3  E0  10/08/2019  15:00         Burnley  ...    1.90     2.07     1.86    2.02
# 4  E0  10/08/2019  15:00  Crystal Palace  ...    2.03     2.08     1.96    1.93
#
# [5 rows x 106 columns]

# %%
# get games where the home team scored 5 or more goals
df.query('FTHG > 5')
# Out:
#    Div        Date   Time  HomeTeam  ... MaxCAHH  MaxCAHA  AvgCAHH AvgCAHA
# 54  E0  21/09/2019  15:00  Man City  ...    1.93     2.16     1.88     2.0
#
# [1 rows x 106 columns]

# %%
# get games where the away team scored 5 or more goals
df.query('FTAG >= 5')
# Out:
#    Div        Date   Time     HomeTeam  ... MaxCAHH  MaxCAHA  AvgCAHH AvgCAHA
# 1   E0  10/08/2019  12:30     West Ham  ...    2.07     1.98     1.97    1.92
# 45  E0  14/09/2019  15:00       Wolves  ...    1.86     2.12     1.83    2.06
# 73  E0  05/10/2019  15:00      Norwich  ...    2.16     1.84     2.11    1.80
# 90  E0  25/10/2019  20:00  Southampton  ...    1.97     2.12     1.84    2.06
#
# [4 rows x 106 columns]

# %%
# how many draws?
(df.FTR == 'D').sum()
# Out:
# 50

# %%
# who refereed the most games?
df.Referee.value_counts()
# Out:
# M Atkinson    18
# A Taylor      17
# M Dean        16
# M Oliver      16
# C Kavanagh    15
# P Tierney     14
# K Friend      14
# J Moss        14
# A Marriner    13
# G Scott       12
# C Pawson      11
# S Attwell     11
# L Mason        9
# D Coote        8
# A Madley       6
# S Hooper       6
# P Bankes       5
# T Robinson     1
# R Jones        1
# O Langford     1
# Name: Referee, dtype: int64
